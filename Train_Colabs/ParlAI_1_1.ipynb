# %% [markdown]
# <a href="https://colab.research.google.com/github/shahid-kh/Conversational-AI-with-ParlAI_Facebook/blob/master/Train_Colabs/ParlAI_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/ParlAI.git ~/ParlAI
# Out:
# Cloning into '/root/ParlAI'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 31502 (delta 43), reused 43 (delta 23), pack-reused 31424
# Receiving objects: 100% (31502/31502), 58.96 MiB | 20.38 MiB/s, done.
# Resolving deltas: 100% (22462/22462), done.

# %%
cd ~/ParlAI
# Out:
# /root/ParlAI

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/parlai.egg-link (link to .)
# parlai 0.1.20200731 is already the active version in easy-install.pth
# Installing parlai script to /usr/local/bin
#
# Installed /root/ParlAI
# Processing dependencies for parlai==0.1.20200731
# Searching for commonmark>=0.8.1
# Reading https://pypi.org/simple/commonmark/
# ...
# Best match: commonmark 0.9.1
# Processing commonmark-0.9.1-py2.py3-none-any.whl
# Installing commonmark-0.9.1-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# ...

# %%
# !pip install 'Sphinx==3.1.2'
# Out:
# ...
#      |████████████████████████████████| 2.9MB 7.2MB/s
# ...
#      |████████████████████████████████| 102kB 11.4MB/s
# ...
#      |████████████████████████████████| 92kB 8.9MB/s
# ...
#      |████████████████████████████████| 92kB 10.8MB/s
# ...
#      |████████████████████████████████| 92kB 9.6MB/s
# ...
#      |████████████████████████████████| 122kB 48.8MB/s
# ...
# ERROR: recommonmark 0.6.0 requires commonmark>=0.8.1, which is not installed.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: Sphinx 1.8.5
#     Uninstalling Sphinx-1.8.5:
#       Successfully uninstalled Sphinx-1.8.5
# ...

# %%
# !parlai train_model -t personachat -m transformer/ranker -mf /tmp/model_tr6 --n-layers 1 --embedding-size 300 --ffn-size 600 --n-heads 4 --num-epochs 2 -veps 0.25 -bs 64 -lr 0.001 --dropout 0.1 --embedding-type fasttext_cc --candidates batch
# Out:
# 14:41:59 INFO | building dictionary first...
# 14:41:59 INFO | creating task(s): personachat
# [building data: /root/ParlAI/data/Persona-Chat]
# 14:41:59 INFO | Downloading http://parl.ai/downloads/personachat/personachat.tgz to /root/ParlAI/data/Persona-Chat/personachat.tgz
# ...
# 14:42:31 INFO | loading fbdialog data: /root/ParlAI/data/Persona-Chat/personachat/train_self_original.txt
# Building dictionary:   0% 0.00/65.7k [00:00<?, ?ex/s]14:42:31 INFO | loading fbdialog data: /root/ParlAI/data/Persona-Chat/personachat/train_self_original.txt
# Building dictionary: 100% 65.7k/65.7k [00:04<00:00, 16.0kex/s]
# 14:42:35 INFO | Saving dictionary to /tmp/model_tr6.dict
# 14:42:35 INFO | dictionary built with 18745 tokens in 0.0s
# 14:42:35 INFO | No model with opt yet at: /tmp/model_tr6(.opt)
# 14:42:35 INFO | loading dictionary from /tmp/model_tr6.dict
# 14:42:36 INFO | num words = 18745
# /root/ParlAI/data/models/fasttext_cc_vectors/crawl-300d-2M.vec.zip: 1.52GB [02:21, 10.7MB/s]
# ...
